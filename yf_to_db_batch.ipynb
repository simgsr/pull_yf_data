# %%
import yf_to_df_folder as pull_folder
pull_folder.process_multiple_csv_files('input_csv', delay_minutes=3)

# %%
import os
import time
import pandas as pd
from yf_to_db import main  # Import the main function from your script

def process_multiple_csv_files(csv_folder_path, delay_minutes=2):
    """
    Process multiple CSV files containing tickers with delays between each file
    
    Args:
        csv_folder_path (str): Path to the folder containing CSV files
        delay_minutes (int): Delay in minutes between processing each CSV file
    """
    # Get all CSV files in the specified folder
    csv_files = [f for f in os.listdir(csv_folder_path) if f.endswith('.csv')]
    
    if not csv_files:
        print(f"No CSV files found in {csv_folder_path}")
        return
    
    print(f"Found {len(csv_files)} CSV files to process")
    
    # Process each CSV file
    for i, csv_file in enumerate(csv_files):
        csv_path = os.path.join(csv_folder_path, csv_file)
        
        print(f"\n{'='*50}")
        print(f"Processing file {i+1}/{len(csv_files)}: {csv_file}")
        print(f"{'='*50}")
        
        # Process the current CSV file
        try:
            financial_data, failed_tickers = main(csv_path)
            
            # Print summary for this file
            print(f"\nSummary for {csv_file}:")
            print(f"Successfully processed: {len(financial_data) - len(failed_tickers)} tickers")
            print(f"Failed to process: {len(failed_tickers)} tickers")
            
        except Exception as e:
            print(f"Error processing {csv_file}: {e}")
        
        # Add delay between files (except after the last file)
        if i < len(csv_files) - 1:
            delay_seconds = delay_minutes * 60
            print(f"\nWaiting {delay_minutes} minutes before processing next file...")
            time.sleep(delay_seconds)

if __name__ == "__main__":
    # Specify the path to your folder containing CSV files
    csv_folder = "input_csv"  # Update this path as needed
    
    # Process all CSV files with 5-minute delays
    process_multiple_csv_files(csv_folder, delay_minutes=5)
# Out:
# Found 28 CSV files to process
#
# ==================================================
# Processing file 1/28: group_Exchange Country_HK_Exchange_part1.csv
# ==================================================
#
# Processing 500 tickers: 0001.hk, 0002.hk, 0003.hk, 0004.hk, 0005.hk, 0006.hk, 0008.hk, 0010.hk, 0011.hk, 0012.hk, 0013.hk, 0014.hk, 0016.hk, 0017.hk, 0018.hk, 0019.hk, 0020.hk, 0021.hk, 0022.hk, 0023.hk, 0025.hk, 0026.hk, 0027.hk, 0028.hk, 0029.hk, 0030.hk, 0031.hk, 0032.hk, 0033.hk, 0034.hk, 0035.hk, 0036.hk, 0037.hk, 0038.hk, 0039.hk, 0040.hk, 0041.hk, 0042.hk, 0045.hk, 0046.hk, 0048.hk, 0050.hk, 0051.hk, 0052.hk, 0053.hk, 0055.hk, 0057.hk, 0058.hk, 0059.hk, 0060.hk, 0061.hk, 0062.hk, 0063.hk, 0064.hk, 0065.hk, 0066.hk, 0069.hk, 0070.hk, 0071.hk, 0072.hk, 0073.hk, 0075.hk, 0076.hk, 0077.hk, 0078.hk, 0079.hk, 0080.hk, 0081.hk, 0082.hk, 0083.hk, 0084.hk, 0085.hk, 0086.hk, 0087.hk, 0088.hk, 0089.hk, 0090.hk, 0092.hk, 0093.hk, 0094.hk, 0095.hk, 0096.hk, 0097.hk, 0098.hk, 0099.hk, 0101.hk, 0103.hk, 0104.hk, 0105.hk, 0106.hk, 0107.hk, 0108.hk, 0110.hk, 0111.hk, 0113.hk, 0114.hk, 0115.hk, 0116.hk, 0117.hk, 0118.hk, 0119.hk, 0120.hk, 0122.hk, 0123.hk, 0124.hk, 0125.hk, 0126.hk, 0127.hk, 0128.hk, 0129.hk, 0130.hk, 0131.hk, 0132.hk, 0133.hk, 0135.hk, 0136.hk, 0137.hk, 0138.hk, 0139.hk, 0142.hk, 0144.hk, 0145.hk, 0146.hk, 0147.hk, 0148.hk, 0149.hk, 0150.hk, 0151.hk, 0152.hk, 0154.hk, 0156.hk, 0157.hk, 0158.hk, 0159.hk, 0160.hk, 0162.hk, 0163.hk, 0164.hk, 0165.hk, 0166.hk, 0167.hk, 0168.hk, 0169.hk, 0171.hk, 0173.hk, 0174.hk, 0175.hk, 0176.hk, 0177.hk, 0178.hk, 0179.hk, 0180.hk, 0181.hk, 0182.hk, 0183.hk, 0184.hk, 0185.hk, 0186.hk, 0187.hk, 0188.hk, 0189.hk, 0191.hk, 0193.hk, 0194.hk, 0195.hk, 0196.hk, 0197.hk, 0199.hk, 0200.hk, 0201.hk, 0202.hk, 0204.hk, 0205.hk, 0206.hk, 0207.hk, 0209.hk, 0210.hk, 0211.hk, 0212.hk, 0213.hk, 0214.hk, 0215.hk, 0216.hk, 0217.hk, 0218.hk, 0219.hk, 0220.hk, 0222.hk, 0223.hk, 0224.hk, 0225.hk, 0227.hk, 0228.hk, 0229.hk, 0230.hk, 0232.hk, 0234.hk, 0235.hk, 0236.hk, 0237.hk, 0239.hk, 0240.hk, 0241.hk, 0242.hk, 0243.hk, 0244.hk, 0245.hk, 0247.hk, 0248.hk, 0251.hk, 0252.hk, 0253.hk, 0254.hk, 0255.hk, 0256.hk, 0257.hk, 0258.hk, 0259.hk, 0261.hk, 0262.hk, 0264.hk, 0265.hk, 0266.hk, 0267.hk, 0268.hk, 0269.hk, 0270.hk, 0271.hk, 0272.hk, 0274.hk, 0276.hk, 0277.hk, 0279.hk, 0280.hk, 0285.hk, 0286.hk, 0287.hk, 0288.hk, 0289.hk, 0290.hk, 0291.hk, 0293.hk, 0294.hk, 0295.hk, 0296.hk, 0297.hk, 0298.hk, 0299.hk, 0300.hk, 0301.hk, 0302.hk, 0303.hk, 0305.hk, 0306.hk, 0308.hk, 0309.hk, 0310.hk, 0311.hk, 0312.hk, 0313.hk, 0314.hk, 0315.hk, 0316.hk, 0317.hk, 0318.hk, 0320.hk, 0321.hk, 0322.hk, 0323.hk, 0325.hk, 0326.hk, 0327.hk, 0328.hk, 0329.hk, 0330.hk, 0331.hk, 0332.hk, 0333.hk, 0334.hk, 0335.hk, 0336.hk, 0337.hk, 0338.hk, 0339.hk, 0340.hk, 0341.hk, 0343.hk, 0345.hk, 0346.hk, 0347.hk, 0348.hk, 0351.hk, 0352.hk, 0353.hk, 0354.hk, 0355.hk, 0356.hk, 0357.hk, 0358.hk, 0360.hk, 0361.hk, 0362.hk, 0363.hk, 0365.hk, 0366.hk, 0367.hk, 0368.hk, 0369.hk, 0370.hk, 0371.hk, 0372.hk, 0373.hk, 0374.hk, 0375.hk, 0376.hk, 0377.hk, 0379.hk, 0380.hk, 0381.hk, 0382.hk, 0383.hk, 0384.hk, 0385.hk, 0386.hk, 0387.hk, 0388.hk, 0389.hk, 0390.hk, 0391.hk, 0392.hk, 0393.hk, 0396.hk, 0397.hk, 0398.hk, 0399.hk, 0400.hk, 0401.hk, 0403.hk, 0406.hk, 0408.hk, 0410.hk, 0411.hk, 0412.hk, 0413.hk, 0417.hk, 0418.hk, 0419.hk, 0420.hk, 0422.hk, 0423.hk, 0425.hk, 0426.hk, 0428.hk, 0430.hk, 0431.hk, 0432.hk, 0433.hk, 0434.hk, 0436.hk, 0438.hk, 0439.hk, 0440.hk, 0442.hk, 0444.hk, 0450.hk, 0451.hk, 0455.hk, 0456.hk, 0458.hk, 0459.hk, 0460.hk, 0464.hk, 0465.hk, 0467.hk, 0468.hk, 0471.hk, 0472.hk, 0474.hk, 0475.hk, 0476.hk, 0480.hk, 0482.hk, 0483.hk, 0484.hk, 0485.hk, 0486.hk, 0487.hk, 0488.hk, 0489.hk, 0491.hk, 0493.hk, 0495.hk, 0496.hk, 0497.hk, 0498.hk, 0499.hk, 0500.hk, 0505.hk, 0506.hk, 0508.hk, 0509.hk, 0510.hk, 0511.hk, 0512.hk, 0513.hk, 0515.hk, 0517.hk, 0518.hk, 0519.hk, 0520.hk, 0521.hk, 0522.hk, 0524.hk, 0525.hk, 0526.hk, 0527.hk, 0528.hk, 0529.hk, 0532.hk, 0533.hk, 0535.hk, 0536.hk, 0538.hk, 0540.hk, 0542.hk, 0543.hk, 0544.hk, 0546.hk, 0547.hk, 0548.hk, 0551.hk, 0552.hk, 0553.hk, 0554.hk, 0556.hk, 0557.hk, 0558.hk, 0559.hk, 0560.hk, 0563.hk, 0564.hk, 0565.hk ...
# Error fetching data for 0144.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0144.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0145.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0145.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0146.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0146.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0147.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0147.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0148.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0148.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0149.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0149.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0154.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0154.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0239.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0239.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0256.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0256.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0264.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0264.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0267.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0267.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0268.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0268.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0269.hk: Expecting value: line 1 column 1 (char 0)
# Failed to process 0269.hk: Expecting value: line 1 column 1 (char 0)
# Error fetching data for 0574.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0574.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0575.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0575.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0576.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0576.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0579.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0579.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0580.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0580.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0581.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0581.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0582.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0582.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0583.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0583.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0585.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0585.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0586.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0586.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0587.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0587.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0588.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0588.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0590.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0590.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0591.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0591.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0595.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0595.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0596.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0596.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0598.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0598.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0599.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0599.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0601.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0601.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0602.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0602.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0603.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0603.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0604.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0604.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0605.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0605.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0606.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0606.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0607.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0607.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0608.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0608.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0609.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0609.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0610.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0610.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0611.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0611.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0612.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0612.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0613.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0613.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0616.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0616.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0617.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0617.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0618.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0618.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0619.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0619.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0620.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0620.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0621.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0621.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0622.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0622.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0623.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0623.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0626.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0626.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0627.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0627.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0628.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0628.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0629.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0629.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0630.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0630.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0631.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0631.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0632.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0632.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0635.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0635.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0636.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0636.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0637.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0637.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0639.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0639.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0640.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0640.hk: Too Many Requests. Rate limited. Try after a while.
# Error fetching data for 0641.hk: Too Many Requests. Rate limited. Try after a while.
# Failed to process 0641.hk: Too Many Requests. Rate limited. Try after a while.
# Updated yf_data.csv with 435 equity records
#
# Failed to process 65 tickers:
#   - 0144.hk
#   - 0145.hk
#   - 0146.hk
#   - 0147.hk
#   - 0148.hk
#   - 0149.hk
#   - 0154.hk
#   - 0239.hk
#   - 0256.hk
#   - 0264.hk
#   - 0267.hk
#   - 0268.hk
#   - 0269.hk
#   - 0574.hk
#   - 0575.hk
#   - 0576.hk
#   - 0579.hk
#   - 0580.hk
#   - 0581.hk
#   - 0582.hk
#   - 0583.hk
#   - 0585.hk
#   - 0586.hk
#   - 0587.hk
#   - 0588.hk
#   - 0590.hk
#   - 0591.hk
#   - 0595.hk
#   - 0596.hk
#   - 0598.hk
#   - 0599.hk
#   - 0601.hk
#   - 0602.hk
#   - 0603.hk
#   - 0604.hk
#   - 0605.hk
#   - 0606.hk
#   - 0607.hk
#   - 0608.hk
#   - 0609.hk
#   - 0610.hk
#   - 0611.hk
#   - 0612.hk
#   - 0613.hk
#   - 0616.hk
#   - 0617.hk
#   - 0618.hk
#   - 0619.hk
#   - 0620.hk
#   - 0621.hk
#   - 0622.hk
#   - 0623.hk
#   - 0626.hk
#   - 0627.hk
#   - 0628.hk
#   - 0629.hk
#   - 0630.hk
#   - 0631.hk
#   - 0632.hk
#   - 0635.hk
#   - 0636.hk
#   - 0637.hk
#   - 0639.hk
#   - 0640.hk
#   - 0641.hk
#
# Processing complete!
# Successfully processed equity: 435 tickers
# Failed to process: 65 tickers
#
# Summary for group_Exchange Country_HK_Exchange_part1.csv:
# Successfully processed: 370 tickers
# Failed to process: 65 tickers
#
# Waiting 5 minutes before processing next file...
